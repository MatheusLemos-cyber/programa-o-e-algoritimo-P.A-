# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusLemos-cyber/programa-o-e-algoritimo-P.A-/blob/main/ListaTuplasLista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas = ["maçã", "banana", "laranja", "morango"]

print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]

print(nomes[0])
print(nomes[1])
print(nomes[-1])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
cores = ["vermelho", "azul", "verde"]

cores[1] = "amarelo"

print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]

alunos.append("Petros")

print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]

animais.remove("coelho")

print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
numeros = (10, 20, 30, 40, 50)

print(numeros[0])
print(numeros[2])
print(numeros[-1])
# Out:
# 10
# 30
# 50

# %%
aluno = ("João", 15, "Informática")

print("Nome:", aluno[0])
print("Idade:", aluno[1])
print("Curso:", aluno[2])
# Out:
# Nome: João
# Idade: 15
# Curso: Informática

# %%
cores = ("vermelho", "azul", "verde")

cores(1) = "amarelo"

print(cores)
# Out:
#   File "/tmp/ipykernel_1592/899513396.py", line 3
#     cores(1) = "amarelo"
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)

quantidade = numeros.count(2)

print(quantidade)
# Out:
# 3
