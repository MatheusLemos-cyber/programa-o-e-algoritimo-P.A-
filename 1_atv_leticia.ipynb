# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusLemos-cyber/programa-o-e-algoritimo-P.A-/blob/main/1_atv_leticia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#criar as variaveis usando print e type
#nome
#idade
#altura
#nota
#cidade

nome = str (input("Digite seu nome aqui: "))
idade = int (input("Digite qual sua idade aqui: "))
altura = float (input("Informe sua altura aqui: "))
nota = float (input("Qual sua nota finhal: "))
cidade = str (input("qual sua cidade: "))
print("--------------------------------------------------")
print(nome)
print(type(nome))
print("--------------------------------------------------")
print(idade)
print(type(idade))
print("--------------------------------------------------")
print(altura)
print(type(altura))
print("--------------------------------------------------")
print(nota)
print(type(nota))
print("--------------------------------------------------")
print(cidade)
print(type(cidade))
print("--------------------------------------------------")
# Out:
# Digite seu nome aqui: Matheus
# Digite qual sua idade aqui: 99
# Informe sua altura aqui: 9.0
# Qual sua nota finhal: 10.00
# qual sua cidade: Maua
# --------------------------------------------------
# Matheus
# <class 'str'>
# --------------------------------------------------
# 99
# <class 'int'>
# --------------------------------------------------
# 9.0
# <class 'float'>
# --------------------------------------------------
# 10.0
# <class 'float'>
# --------------------------------------------------
# Maua
# <class 'str'>
# --------------------------------------------------

# %%
#fazer um programa para tirar a media das seguintes notas 6.5,7.5,8.0

nota1 = 6.5
nota2 = 7.5
nota3 = 8.0

notaF = (nota1 + nota2 + nota3) / 3

print(f"Sua media final foi igual a {notaF}")
# Out:
# Sua media final foi igual a 7.333333333333333

# %%
#faça as converções e mostre o resultado

texto1 = "20"
texto2 = "3.5"
numero = 8

texto1NUM = int("20")
texto2NUM = float("3.5")
numeroTEXT = str("8")

texto1NUM += 10

print(f"o resultado ficou igual a {texto1NUM}")

texto2NUM *= 2
print(f"o resultado ficou igual a {texto2NUM}")

print(f'ficou como {numeroTEXT} anos ')
# Out:
# o resultado ficou igual a 30
# o resultado ficou igual a 7.0
# ficou como 8 anos

# %%
#EXPRESSOES ARITIMETICAS

a = 15
b = 90
c = 17
d = 2
e1 = 10
e2 = 8
e3 = 6

a *= 2
print(f"O resultado ficou como {a}")

b /= 2
print(f"o resultado ficou como {b}")

c %= 5
print(f"o resultado ficou como {c}")

d **= 4
print(f"o resultado ficou como {d}")

media = (e1 + e2 + e3) / 3
print(f"o resultado ficou como {media}")
# Out:
# O resultado ficou como 30
# o resultado ficou como 45.0
# o resultado ficou como 2
# o resultado ficou como 16
# o resultado ficou como 8.0

# %%
#comparações relacionais

nota = 8.5
idade = 16
preco = 45.0

print(f"{idade} {idade >= 18}")
print(f"{nota} {nota >= 7}")
print(f"{preco} {preco <= 50}")
print(f"{idade} {idade == 16}")
print(f"{nota} {nota != 10}")
# Out:
# 16 False
# 8.5 True
# 45.0 True
# 16 True
# 8.5 True

# %%
#situação pratica

produto = 80


desconto = {produto / 10}
print(f" o desconto ficou igual a {desconto}")

valorF = (produto) - (produto / 10)
print(f"o valor dinal a se pagar é igual a {valorF}")

print(f"{valorF} é {valorF <= 75.00}")
# Out:
#  o desconto ficou igual a {8.0}
# o valor dinal a se pagar é igual a 72.0
# 72.0 é True

# %%
nome = str (input("digite o nome do aluno: "))
nota1 = float (input("digite a nota do 1 semestre: "))
nota2 = float (input("digite a nota do 2 semestre: "))

mediaF = (nota1 + nota2) / 2

print(f"a media final do aluno é igual a {mediaF}")
# Out:
# digite o nome do aluno: matheus
# digite a nota do 1 semestre: 8
# digite a nota do 2 semestre: 7
# a media final do alunos é igual a 7.5

# %%
idade = int (input("digite sua idade aqui: "))

if idade >= 18:
  print(f"por você ter {idade} já pode tirar a carteira")

else:
  print(f"infelizmente ainda nao pode tirar a carteira")
# Out:
# digite sua idade aqui: 27
# por você ter 27 já pode tirar a carteira

# %%
num = int (input("digite o numero que deseja descobrir"))

if num % 2 == 0:
  print(f"este numero é par")
else:
  print(f"este numero é impar")
# Out:
# digite o numero que deseja descobrir10
# este numero é par

# %%
num1 = float (input("digite o numero que deseja: "))
num2 =  float (input("digite o numero que deseja: "))


if num1 > num2:
  print(f"o numero {num1} é maior que o {num2}")
elif num1 < num2:
  print(f"o numero {num2} é maior que o numero {num1}")
else:
  print("são numeros iguais")
# Out:
# digite o numero que deseja: 9
# digite o numero que deseja: 10
# o numero 10.0 é maior que o numero 9.0

# %%
notaf = float (input("digite a media final do aluno aqui: "))

if notaf >= 7:
  print(f" o aluno esta aprovado")
elif notaf >= 5:
  print(f" o aluno esta de recuperação")
else:
  print(f" o aluno esta reprovado")
# Out:
# digite a media final do aluno aqui: 10
#  o aluno esta aprovado

# %%
valor = float (input("digite o valor do produto aqui: "))

if valor >= 100:
  valorf = (valor) - (valor / 10)
  print(f"o valor final do produto após o desconto ficou igual a {valorf}")
else:
  print(f" o produto custa {valor}")
# Out:
# digite o valor do produto aqui: 99
#  o produto custa 99.0

# %%
num = float (input("digite o numero aqui: "))

if num > 0:
  print(f"este numero é positivo")
elif num < 0:
  print(f"este numero é negativo")
elif num == 0:
  print(f"este numero é 0")
# Out:
# digite o numero aqui: 2
# este numero é positivo

# %%
idade = float (input("digite sua idade aqui: "))

if idade >= 60:
  print(f" você já é um idoso")
elif idade >= 18:
  print(f" você é um adulto")
elif idade >= 12:
  print(f"voce é um adolecente ainda")
elif idade <= 11:
  print(f"você é uma criança")
# Out:
# digite sua idade aqui: 13
# voce é um adolecente ainda

# %%
nota1 = float (input("digite a nota do 1 semestre: "))
nota2 = float (input("digite a nota do 2 semestre: "))

mediaF =  (nota1 + nota2) / 2

if mediaF >= 7:
  print(f"o aluno esta aprovado com uma media de {mediaF}")
else:
  print(f"o aluno esta reprovado com uma media de {mediaF}")
# Out:
# digite a nota do 1 semestre: 10
# digite a nota do 2 semestre: 1
# o aluno esta reprovado com uma media de 5.5

# %%
usuario =  input("digite seu usuario: ")
senha =  input("digite sua senha: ")

if usuario == "admin" and senha == "1234":
  print(f"login realizado com sucesso")

else:
  print(f"senha ou usuario incorreto")
# Out:
# digite seu usuario: admin
# digite sua senha: 1234
# login realizado com sucesso

# %%
peso = float (input("digite seu peso aqui: "))
altura = float (input("digite sua altura: "))

imc = (peso / (altura * altura))

if imc >= 30:
  print(f"voce é uma pessoa obesa")
elif imc >= 25:
  print(f"voce esta sobrepeso")
elif imc >= 18.5:
  print(f"voce esta no peso normal")
elif imc <= 18.4:
  print(f"vc esta abaixo do peso")
# Out:
# digite seu peso aqui: 90
# digite sua altura: 1.80
# voce esta sobrepeso
