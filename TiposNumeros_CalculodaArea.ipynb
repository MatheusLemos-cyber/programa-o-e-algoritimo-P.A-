# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusLemos-cyber/programa-o-e-algoritimo-P.A-/blob/main/TiposNumeros_CalculodaArea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Aula de programação e algoritimos
#
#  - Calculo da area
#
#  # Entrada
#
#  - ler lado1
#  - ler lado2
#
#  # Processamento
# area - lado1 * lado2
#
# # Saida
# imprimir area

# %%
# calculo da area

# Entrada

lado1 = 5

lado2 = 4

# %%
# processamento

area = lado1 * lado2

# %%
# saida

print (f"Total da area: {area}")
# Out:
# Total da area: 20

# %%
#tipos de numeros

idade = 15 # int

altura = 1.83 # floot

numero_complexo = 2+3j #complex

#tipo de texto
nome = "matheus" # str

#tipo booleano

esta_chovendo = False # boot
